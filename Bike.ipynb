# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('/content/Sales.csv',parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Customer_Age'].mean()
# Out:
# np.float64(35.91921157861212)

# %%
sales['Cost'].mean()
# Out:
# np.float64(469.3186949290492)

# %%
sales['Customer_Age'].plot(kind='kde',figsize=(7,4))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box',vert = False, figsize = (6,4))
# Out:
# <Axes: >

# %%
sales['Order_Quantity'].mean()
# Out:
# np.float64(11.901659648253654)

# %%
sales['Order_Quantity'].plot(kind='kde', figsize=(7,4))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Order_Quantity'].plot(kind='hist',bins=30, figsize=(7,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert = False, figsize=(6,4))
# Out:
# <Axes: >

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(7,4))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(7,4))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Product'].value_counts()
# Out:
# Product
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches        10416
# Mountain Tire Tube          6816
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
#                            ...
# Mountain-100 Silver, 48       58
# Mountain-100 Silver, 42       54
# Mountain-500 Silver, 48       40
# Road-650 Red, 52              32
# Mountain-500 Black, 52        22
# Name: count, Length: 130, dtype: int64

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Country'>

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Product'>

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts().plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Product_Category'>

# %%
sales['Sub_Category'].value_counts().head(10).plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
sales.plot(kind= 'scatter', x= 'Unit_Price', y='Unit_Cost', figsize=(7,4))
# Out:
# <Axes: xlabel='Unit_Price', ylabel='Unit_Cost'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(7,4))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
sales[['Customer_Age','Country']].boxplot(by='Country')
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# <ipython-input-37-4f7f8083e74d>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Month'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
sales[['Month','Product']].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Month,Product'>

# %%
sales[['Product','Country']].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Product,Country'>

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales['Revenue'] += 50

# %%
sales['Revenue'].head(5)
# Out:
# 0    1000
# 1    1000
# 2    2451
# 3    2138
# 4     468
# Name: Revenue, dtype: int64

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 25176

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'United States')].shape[0]
# Out:
# 53384

# %%
sales.loc[(sales['Country'] == 'France') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 50

# %%
france_state = sales.loc[sales['Country']=='France','State'].value_counts()
france_state
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
United_sales = sales.loc[sales['Country']=='United States', 'Product'].value_counts()

# %%
United_sales
# Out:
# Product
# Water Bottle - 30 oz.      4034
# Patch Kit/8 Patches        3674
# Mountain Tire Tube         2946
# Fender Set - Mountain      1844
# Sport-100 Helmet, Black    1584
#                            ...
# Mountain-100 Silver, 38       4
# Road-650 Red, 44              4
# Road-650 Black, 52            4
# Mountain-500 Silver, 52       2
# Road-650 Red, 52              2
# Name: count, Length: 129, dtype: int64

# %%
france_state.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
bike = sales.loc[sales['Product_Category']=='Bikes', 'Sub_Category'].value_counts()

# %%
bike
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bike.plot(kind='bar', figsize=(7,4))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_Gender'>

# %%
sales.loc[(sales['Customer_Gender'] == 'F') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 29

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day  Month  Year  Customer_Age             Age_Group  \
# 112073 2015-07-24   24   July  2015            52        Adults (35-64)
# 112072 2013-07-24   24   July  2013            52        Adults (35-64)
# 71129  2011-07-08    8   July  2011            22           Youth (<25)
# 59919  2011-03-20   20  March  2011            29  Young Adults (25-34)
# 68671  2011-07-05    5   July  2011            26  Young Adults (25-34)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 59919                F    Germany            Bayern            Bikes
# 68671                M     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# np.float64(3.689265536723164)
